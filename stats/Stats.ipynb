# %% [markdown]
# # Heart Disease Statistics
#
# __Import libraries__
#
# For visualisation statistics and histograms of data, I use the `matplotlib` library, and Its subpackage `pyplot`.

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
from scipy import stats
import numpy as np

# %% [markdown]
# __Read data__
#
# Read file 'heart.csv' to local variable 'data'

# %%
data = pd.read_csv("heart.csv", sep=",")
data.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
# 7   44    1   1       120   263    0        1      173      0      0.0      2
# 8   52    1   2       172   199    1        1      162      0      0.5      2
# 9   57    1   2       150   168    0        1      174      0      1.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# ...

# %% [markdown]
# __Age distribution in data__

# %%
sns.distplot(data['age'],rug=True)
plt.show()

# %% [markdown]
# __Sex distribution in data__

# %%
sns.countplot(x='sex', data=data)
plt.xlabel("Sex (0 = female, 1= male)")
plt.show()

# %%
pd.crosstab(data.sex,data.target).plot(kind="bar",figsize=(10,5))
plt.xlabel('Sex (0 = Female, 1 = Male)')
plt.xticks(rotation=0)
plt.legend(["Haven't Disease", "Have Disease"])
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Women are 4 times more likely to die from heart disease than breast cancer

# %% [markdown]
# __Fasting blood sugar__
#
# Fasting blood sugar >120
# - 0 - false
# - 1 - true

# %%
sns.countplot(x='fbs', data=data)
plt.xlabel('FBS - (Fasting Blood Sugar > 120 mg/dl)')
plt.show()

# %%
pd.crosstab(data.fbs,data.target).plot(kind="bar",figsize=(10,5))
plt.xlabel('FBS - (Fasting Blood Sugar > 120 mg/dl) (1 = true; 0 = false)')
plt.xticks(rotation = 0)
plt.legend(["Haven't Disease", "Have Disease"])
plt.ylabel('Frequency of Disease or Not')
plt.show()

# %% [markdown]
# __Chest pain type distribution__
#
# - 0 - asymptomatic
# - 1 - atypical
# - 2 - non-anginal pain
# - 3 - typical angina

# %%
sns.countplot(x='cp', data=data)
plt.xlabel('Chest Pain Type')
plt.show()

# %%
pd.crosstab(data.cp,data.target).plot(kind="bar",figsize=(10,5))
plt.xlabel('Chest Pain Type')
plt.xticks(rotation = 0)
plt.ylabel('Frequency of Disease or Not')
plt.show()

# %% [markdown]
# __Thalach__
#
# Maximum heart rate achieved

# %%
sns.barplot(x=data.thalach.value_counts()[:10].index,y=data.thalach.value_counts()[:10].values)
plt.xlabel('max heart rate')
plt.ylabel('Counter')
plt.show()

# %%
pd.crosstab(data.thalach,data.target).plot(kind="bar",figsize=(100,100))
plt.xlabel('Heart Rate')
plt.xticks(rotation = 0)
plt.ylabel('Frequency of Disease or Not')
plt.show()

# %%
sns.distplot(data['thalach'],rug=True)
plt.show()

# %% [markdown]
# __CA__
#
# Number of major vessels colored by flouroscopy

# %%
sns.countplot(x='ca', data=data)
plt.xlabel('Number of major vessels')
plt.show()

# %%
pd.crosstab(data.ca,data.target).plot(kind="bar",figsize=(10,5))
plt.xlabel('Number of major vessels')
plt.xticks(rotation = 0)
plt.ylabel('Frequency of Disease or Not')
plt.show()

# %% [markdown]
# __Restecg__
#
# Resting electrographic results.
# - 0 - showing probable or definite left venticular hypertrophy by Estes' criteria
# - 1 - normal
# - 2 - having ST-T wave abnormality (T wave inversions and/or ST devation or depression of > 0.05 mV)

# %%
sns.countplot(x='restecg', data=data)
plt.xlabel('Electrographic results')
plt.show()

# %%
pd.crosstab(data.restecg,data.target).plot(kind="bar",figsize=(10,5))
plt.xlabel('Electrographic results')
plt.xticks(rotation = 0)
plt.ylabel('Frequency of Disease or Not')
plt.show()

# %% [markdown]
# __Slope__
#
# The slope of the peak exercise ST segment
# - 0 - downsloping
# - 1 - flat
# - 2 - unslopping

# %%
sns.countplot(x='slope', data=data)
plt.xlabel('Slope')
plt.show()

# %%
pd.crosstab(data.slope,data.target).plot(kind="bar",figsize=(10,5))
plt.xlabel('Slope')
plt.xticks(rotation = 0)
plt.ylabel('Frequency of Disease or Not')
plt.show()

# %% [markdown]
# __Trestbps__
#
# Resting blood pressure(in mm Hg on admission to the hospital)

# %%
sns.distplot(data['trestbps'],rug=True)
plt.show()

# %% [markdown]
# __Chol__
#
# Serum chorestoral in mg/dl

# %%
sns.distplot(data['chol'],rug=True)
plt.show()

# %% [markdown]
# __Exang__
#
# Exercise induced angina
# - 0 - No
# - 1 - Yes

# %%
sns.countplot(x='exang', data=data)
plt.xlabel('Exercise induced angina')
plt.show()

# %%
pd.crosstab(data.exang,data.target).plot(kind="bar",figsize=(10,5))
plt.xlabel('Exercise induced angina')
plt.xticks(rotation = 0)
plt.ylabel('Frequency of Disease or Not')
plt.show()

# %% [markdown]
# __Oldpeak__
#
# ST depression induced by exercise relative to rest.

# %%
sns.distplot(data['oldpeak'],rug=True)
plt.show()

# %% [markdown]
# __Thal__
#
# A blood disorder
# - 1 - normal
# - 2 - defect
# - 3 - reversable defect

# %%
sns.countplot(x='thal', data=data)
plt.xlabel('Thalium')
plt.show()

# %%
pd.crosstab(data.thal,data.target).plot(kind="bar",figsize=(10,5))
plt.xlabel('Thalium')
plt.xticks(rotation = 0)
plt.ylabel('Frequency of Disease or Not')
plt.show()
